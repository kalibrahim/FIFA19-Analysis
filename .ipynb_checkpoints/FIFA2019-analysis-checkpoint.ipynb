# %% [markdown]
# # FIFA 2019 Player Value Prediction

# %% [markdown]
# ## 1. Business Understading:
# This project is for the Udacity Data Science Nanodegree. The purpose of this project is to analyze a select dataset and come up with a detailed analysis based on the business question. Being a football (soccer) fan made me select FIFA19 dataset from Kaggle.
#
# I have come up with the following 3 questions to understand the dataset better:
# 1. How Does Age Effect Players Ratings?
# 2. How Does The Player’s Overall and Age Effect Their Value and Wage?
# 3. Where’s The Money At? / How does the distribution of players over teams can constribute to winning titles?
#
# I have selected these questions based on the way FIFA19 has rated players for the video game and how do they base it on real life. A lot of player are expected to drop in overall performance when they get older, so I wanted to see how much of a effect does age have on their overall rating and selected attributes.
#
# When a player started to not perform as well as he used to, his value tends to drop and his wage does too. So in this analysis I wanted to figure out if that is true for most player.
#
# For the last question, There has been a trend lastly of clubs with higher spending win more titles. So I wanted to understand if that is true and how much of a difference does it make?

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
# %matplotlib inline

df = pd.read_csv('./data.csv')

# %% [markdown]
# ## 2. Data Understanding:
#
# This dataset was pulled from Kaggle.com and sofifa.com. The data seems to be cleaned out for the most part.

# %%
df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
df = df.drop(['Unnamed: 0', 'Photo', 'Flag', 'Club Logo'], axis =1)

# %%
df.describe()
# Out:
#                   ID           Age       Overall     Potential       Special  \
# count   18207.000000  18207.000000  18207.000000  18207.000000  18207.000000
# mean   214298.338606     25.122206     66.238699     71.307299   1597.809908
# std     29965.244204      4.669943      6.908930      6.136496    272.586016
# min        16.000000     16.000000     46.000000     48.000000    731.000000
# 25%    200315.500000     21.000000     62.000000     67.000000   1457.000000
# 50%    221759.000000     25.000000     66.000000     71.000000   1635.000000
# 75%    236529.500000     28.000000     71.000000     75.000000   1787.000000
# max    246620.000000     45.000000     94.000000     95.000000   2346.000000
#
#        International Reputation     Weak Foot   Skill Moves  Jersey Number  \
# count              18159.000000  18159.000000  18159.000000   18147.000000
# mean                   1.113222      2.947299      2.361308      19.546096
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 85 columns):
# ID                          18207 non-null int64
# Name                        18207 non-null object
# Age                         18207 non-null int64
# Nationality                 18207 non-null object
# Overall                     18207 non-null int64
# Potential                   18207 non-null int64
# Club                        17966 non-null object
# Value                       18207 non-null object
# Wage                        18207 non-null object
# Special                     18207 non-null int64
# Preferred Foot              18159 non-null object
# International Reputation    18159 non-null float64
# Weak Foot                   18159 non-null float64
# Skill Moves                 18159 non-null float64
# Work Rate                   18159 non-null object
# Body Type                   18159 non-null object
# Real Face                   18159 non-null object
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club',
#        'Value', 'Wage', 'Special', 'Preferred Foot',
#        'International Reputation', 'Weak Foot', 'Skill Moves', 'Work Rate',
#        'Body Type', 'Real Face', 'Position', 'Jersey Number', 'Joined',
#        'Loaned From', 'Contract Valid Until', 'Height', 'Weight', 'LS', 'ST',
#        'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM', 'LCM',
#        'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB',
#        'RCB', 'RB', 'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing',
#        'Volleys', 'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing',
#        'BallControl', 'Acceleration', 'SprintSpeed', 'Agility', 'Reactions',
#        'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots',
#        'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties',
#        'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving',
# ...

# %%
df.shape[0]
# Out:
# 18207

# %%
df.isnull().sum()
# Out:
# ID                              0
# Name                            0
# Age                             0
# Nationality                     0
# Overall                         0
# Potential                       0
# Club                          241
# Value                           0
# Wage                            0
# Special                         0
# Preferred Foot                 48
# International Reputation       48
# Weak Foot                      48
# Skill Moves                    48
# Work Rate                      48
# Body Type                      48
# Real Face                      48
# Position                       60
# Jersey Number                  60
# Joined                       1553
# Loaned From                 16943
# Contract Valid Until          289
# Height                         48
# Weight                         48
# LS                           2085
# ST                           2085
# RS                           2085
# ...

# %%
print(df['Nationality'].value_counts().head(10))
# Out:
# England        1662
# Germany        1198
# Spain          1072
# Argentina       937
# France          914
# Brazil          827
# Italy           702
# Colombia        618
# Japan           478
# Netherlands     453
# Name: Nationality, dtype: int64

# %% [markdown]
# ## 3. Prepare Data
# For this step I will:
# * Drop unused columns
# * Feature engineer attributes

# %%
df = df.drop(['Loaned From'], axis=1)

# %%
def value_to_int(df_val):
    """
    This function will turn values in value and wage from 100M and 50K to a float value. 
    If the value doesnt have `M` or `K` the number will be back as is.
    
    Parameter: 
        df_val(string): df_val string with M & K as abbreviations for million and thousands
        
    Returns:
        float: A float number represents the value of the input
        parameter df_val(str)
    """
    
    try:
        val = float(df_val[1:-1])
        suffix = df_val[-1:]
        
        if suffix == 'M':
            val = val * 1000000
        elif suffix == 'K':
            val = val * 1000
    except ValueError:
        val = 0
    return val

df['Value'] = df['Value'].apply(value_to_int)
df['Wage'] = df['Wage'].apply(value_to_int)

# %% [markdown]
# ## 4. Modeling / Answer Questions
# #### Q1: How Does Age Effect Players Ratings?

# %% [markdown]
# Let's analyze the players potential according to their age

# %%
sns.jointplot(x=df['Age'], y=df['Potential'],
             height=10, ratio=3, color='b')
# Out:
# /Users/khalid/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.set(style ="dark", palette="winter", color_codes=True)
x = df.Age
plt.figure(figsize=(16,8))
ax = sns.distplot(x, bins = 58, kde=True)
ax.set_xlabel(xlabel = "Player's Age", fontsize=12)
ax.set_ylabel(ylabel = "Number of Players", fontsize=12)
ax.set_title(label = "Players' Age Histogram", fontsize=18)
plt.show()
# Out:
# /Users/khalid/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# Sprint Speed
sns.lmplot(data= df, x = 'Age', y = 'SprintSpeed', lowess=True, 
           scatter_kws={'alpha': 0.01, 's': 5, 'color': 'blue'},
          line_kws={'color': 'red'})

# %%
#Agility
sns.lmplot(data= df, x = 'Age', y = 'Agility', lowess=True, 
           scatter_kws={'alpha': 0.01, 's': 5, 'color': 'blue'},
          line_kws={'color': 'red'})

# %%
#Balance 
sns.lmplot(data= df, x = 'Age', y = 'Balance', lowess=True, 
           scatter_kws={'alpha': 0.01, 's': 5, 'color': 'blue'},
          line_kws={'color': 'red'})

# %%
# Stamina
sns.lmplot(data= df, x = 'Age', y = 'Stamina', lowess=True, 
           scatter_kws={'alpha': 0.01, 's': 5, 'color': 'blue'},
          line_kws={'color': 'red'})

# %%
#Vision
sns.lmplot(data= df, x = 'Age', y = 'Vision', lowess=True, 
           scatter_kws={'alpha': 0.01, 's': 5, 'color': 'blue'},
          line_kws={'color': 'red'})

# %%
#ShotPower
sns.lmplot(data= df, x = 'Age', y = 'ShotPower', lowess=True, 
           scatter_kws={'alpha': 0.01, 's': 5, 'color': 'blue'},
          line_kws={'color': 'red'})

# %%
#Overall
sns.lmplot(data= df, x = 'Age', y = 'Overall', lowess=True, 
           scatter_kws={'alpha': 0.01, 's': 5, 'color': 'blue'},
          line_kws={'color': 'red'})

# %% [markdown]
# We can see that the players' potential drops as they grow older.
# Older players have low potential and there are exception for some old players with high potential. However past the age of 40, you see a huge drop in potential.
#
# I notice that there's always a drop in ability performance, the older the player get. Although that wasn't the case for `Vision`, where the player's vision trend increased as they got older.

# %%
att_cols = ['Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys',
       'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl',
       'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance',
       'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots',
       'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties',
       'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving',
       'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes']

i = 0
while i < len(att_cols):
    print('Best {0}: {1}'.format(att_cols[i], df.loc[df[att_cols[i]].idxmax()][1]))
    i += 1
# Out:
# Best Crossing: K. De Bruyne
# Best Finishing: L. Messi
# Best HeadingAccuracy: Naldo
# Best ShortPassing: L. Modrić
# Best Volleys: E. Cavani
# Best Dribbling: L. Messi
# Best Curve: Quaresma
# Best FKAccuracy: L. Messi
# Best LongPassing: T. Kroos
# Best BallControl: L. Messi
# Best Acceleration: Douglas Costa
# Best SprintSpeed: K. Mbappé
# Best Agility: Neymar Jr
# Best Reactions: Cristiano Ronaldo
# Best Balance: Bernard
# Best ShotPower: Cristiano Ronaldo
# Best Jumping: Cristiano Ronaldo
# Best Stamina: N. Kanté
# Best Strength: A. Akinfenwa
# Best LongShots: L. Messi
# Best Aggression: B. Pearson
# Best Interceptions: N. Kanté
# Best Positioning: Cristiano Ronaldo
# Best Vision: L. Messi
# Best Penalties: M. Balotelli
# Best Composure: L. Messi
# Best Marking: A. Barzagli
# Best StandingTackle: G. Chiellini
# Best SlidingTackle: Sergio Ramos
# Best GKDiving: De Gea
# Best GKHandling: J. Oblak
# Best GKKicking: M. Neuer
# Best GKPositioning: G. Buffon
# Best GKReflexes: De Gea

# %% [markdown]
# Let's find out players with the highest potential and highest overall performance

# %%
print('Highest Overall: {0}'.format(df.loc[df['Overall'].idxmax()][1]))
print('Highest Potential: {0}'.format(df.loc[df['Potential'].idxmax()][1]))
# Out:
# Highest Overall: L. Messi
# Highest Potential: K. Mbappé

# %% [markdown]
# #### Leftie vs Rightie
# Let's compare the `FKAccuracy` control and `ShotPower` based on their foot preference

# %%
sns.lmplot(x='FKAccuracy', y='ShotPower', data=df, col='Preferred Foot', 
           scatter_kws= {'alpha': 0.1, 'color': 'blue'},
          line_kws={'color': 'red'})
# Out:
# /Users/khalid/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# Dribble vs ball control
sns.lmplot(x='BallControl', y='Dribbling', data=df, col='Preferred Foot', 
           scatter_kws= {'alpha': 0.1, 'color': 'blue'},
          line_kws={'color': 'red'})
# Out:
# /Users/khalid/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# It seems that there are more right footed players than left, which we can see in the saturation of dots in the right foot plot. I can also spot that there are more players with high ball control and dribbiling skills that are left footed.

# %%
plt.figure(figsize=(10,6))
sns.countplot(df['Preferred Foot'], palette= 'winter')
plt.title("Most Preferred Players' Foot", fontsize=18)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (20, 8)
plt.style.use('seaborn-dark-palette')

sns.boxenplot(df['Overall'], df['Age'], hue=df['Preferred Foot'], palette = 'winter')
plt.title("Comparison of players' Overall vs. Age with preferred foot", fontsize=18)
plt.show()

# %% [markdown]
# #### Q2: How Does The Player’s Overall and Age Effect Their Value and Wage?

# %%
value = df[['Name','Value']]

print('Most valued players : \n{0}'.format(value.nlargest(5, 'Value')))
# Out:
# Most valued players :
#             Name        Value
# 2      Neymar Jr  118500000.0
# 0       L. Messi  110500000.0
# 4   K. De Bruyne  102000000.0
# 5      E. Hazard   93000000.0
# 15     P. Dybala   89000000.0

# %% [markdown]
# Who are the top earners and most valued players?

# %%
wage = df[['Name', 'Wage']]

print('Highest earning players: \n{0}'.format(wage.nlargest(5, 'Wage')))
# Out:
# Highest earning players:
#                 Name      Wage
# 0           L. Messi  565000.0
# 7          L. Suárez  455000.0
# 6          L. Modrić  420000.0
# 1  Cristiano Ronaldo  405000.0
# 8       Sergio Ramos  380000.0

# %% [markdown]
# ##### Age vs Value

# %%
sns.relplot(x="Age", y='Value',data=df, kind='line', ci=None)

# %% [markdown]
# ##### Age vs Wage

# %%
sns.relplot(x="Age", y='Wage',data=df, kind='line', ci=None)

# %% [markdown]
# ##### Overall vs. Value

# %%
sns.relplot(x="Overall", y='Value', data=df, kind='line', ci=None)

# %% [markdown]
# ##### Overall vs. Wage

# %%
sns.relplot(x="Overall", y='Wage',data=df, kind='line', ci=None)

# %%
sns.relplot(x="Wage", y='Value',data=df, kind='line', ci=None)

# %% [markdown]
# From the plots above, we can see that there is a high correlation between player's overall and wage/value. As the overall gets higher the value of the player gets higher too. As for the age and value/wage, players between 21 - 30 years peak with their salary and market value. For the majority of players once they are past 30 their value and wage starts to decreaase.

# %% [markdown]
# #### Q3: How does the distribution of players over teams can constribute to winning titles?

# %%
pop_clubs = ('Juventus', 'Real Madrid', 'FC Barcelona', 
             'Manchester City','Paris Saint-Germain', 'Ajax', 
             'Arsenal', 'Chelsea', 'FC Bayern München', 'Milan',
            'Roma', 'Liverpool')

club_value = df.loc[df['Club'].isin(pop_clubs) & df['Value']]

plt.rcParams['figure.figsize'] = (12, 8)
ax = sns.boxplot(x = club_value['Club'], y = club_value['Value'], 
                 palette='winter')
ax.set_xlabel(xlabel= 'Popular Clubs', fontsize=10)
ax.set_ylabel(ylabel= 'Players Value', fontsize=10)
ax.set_title(label='Distribution of Players Value in Popular Clubs', fontsize=20)
plt.xticks(rotation=90)
plt.show()

# %%
pop_nat = ('Spain', 'Italy', 'England', 'France','Germany', 
                 'Brazil','Argentina', 'Colombia', 'Japan', 'Portugal')

nat_value = df.loc[df['Nationality'].isin(pop_nat) & df['Value']]

plt.rcParams['figure.figsize'] = (12, 8)
ax = sns.barplot(x = nat_value['Nationality'], y = nat_value['Value'], 
                 palette='winter')
ax.set_xlabel(xlabel= 'Popular Nationalities', fontsize=10)
ax.set_ylabel(ylabel= 'Players Value', fontsize=10)
ax.set_title(label='Distribution of Players Value in Popular Nationalities', fontsize=20)
plt.xticks(rotation=90)
plt.show()
# Out:
# /Users/khalid/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
pop_clubs = ('Juventus', 'Real Madrid', 'FC Barcelona', 
             'Manchester City','Paris Saint-Germain', 'Ajax', 
             'Arsenal', 'Chelsea', 'FC Bayern München', 'Milan',
            'Roma', 'Liverpool')

club_overall = df.loc[df['Club'].isin(pop_clubs) & df['Overall']]

plt.rcParams['figure.figsize'] = (12, 8)
ax = sns.boxplot(x = club_overall['Club'], y = club_overall['Overall'], 
                 palette='winter')
ax.set_xlabel(xlabel= 'Popular Clubs', fontsize=10)
ax.set_ylabel(ylabel= 'Players Overall', fontsize=10)
ax.set_title(label='Distribution of Players Overall in Popular Clubs', fontsize=20)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# From the plots above, we can see that big clubs like Barcelona, Manchester City are willing to spend more, which keeps them more competitve in their league and in other competitions. Though, this does not fully constirbute to winning the most prestegous title in football, which is the Champions League, which Liverpool won without spending these astronomial figures on their squad.

# %% [markdown]
# ### Correlation
# Lets find the correlation of all of these attributes and how can they effect the player's value.

# %%
plt.figure(figsize=(16,16))
sns.heatmap(df.corr(), linewidths=0.2, linecolor='black', square=True, cmap='winter')

# %% [markdown]
# ##  5. Model and Measure Prediction

# %% [markdown]
# #### Prepare data for Modeling

# %%
drop_cols = df.columns[28:54]
df = df.drop(drop_cols, axis=1)
df = df.drop(['ID', 'Name', 'Club', 'Special', 'Contract Valid Until',
         'Joined', 'Body Type', 'Release Clause'], axis=1)

df = df.dropna()
df.head()
# Out:
#    Age Nationality  Overall  Potential        Value      Wage Preferred Foot  \
# 0   31   Argentina       94         94  110500000.0  565000.0           Left
# 1   33    Portugal       94         94   77000000.0  405000.0          Right
# 2   26      Brazil       92         93  118500000.0  290000.0          Right
# 4   27     Belgium       91         92  102000000.0  355000.0          Right
# 5   27     Belgium       91         91   93000000.0  340000.0          Right
#
#    International Reputation  Weak Foot  Skill Moves    ...     Penalties  \
# 0                       5.0        4.0          4.0    ...          75.0
# 1                       5.0        4.0          5.0    ...          85.0
# 2                       5.0        5.0          5.0    ...          81.0
# 4                       4.0        5.0          4.0    ...          79.0
# 5                       4.0        4.0          4.0    ...          86.0
#
# ...

# %%
# Turn Real Face into a binary
def face_to_binary(df):
    """
    This function will turn the values `Yes` and `No` into a binary 1 and 0.
    
    Parameter: 
        df['Real Face'](String): A string that represents true or 
        false if the player's real face was modeled.
        
    Returns:
        int: A int number represents if the player has a real face 1 or not 0
    """
    if (df['Real Face'] == 'Yes'):
        return 1
    else:
        return 0

# %%
# Turn Foot preference into binary
def foot_to_binary(df):
    """
    This function turn Preferred Foot into binary 1 and 0. 
    
    Parameter: 
        df['Preferred Foot'](String): A string that represents left or 
        right preffered foot.
        
    Returns:
        int: A int number represents if the player prefers left 1 or 
        right 0 foot
    """
    if (df['Preferred Foot'] == 'Left'):
        return 1
    else:
        return 0

# %%
# Simplify all player position into GK, DF, CDM, CM, CAM, ST
def change_position(df):
    """
    This function simplifies the players' positions into 6 simple positions.
    
    Parameter: 
        df['Position'](String): A string that represents the player's
        position.
        
    Returns:
        string: A string that simplifiys the positions in to 6 positions
    """
    if (df['Position'] == 'GK'):
        return 'GK'
    elif ((df['Position'] == 'RB') | (df['Position'] == 'LB') | (df['Position'] == 'CB') | 
          (df['Position'] == 'RWB') | (df['Position'] == 'LWB') | (df['Position'] == 'RCB') |
          (df['Position'] == 'LCB')):
        return 'DF'
    elif ((df['Position'] == 'RDM') | (df['Position'] == 'CDM') | (df['Position'] == 'LDM')):
        return 'CDM'
    elif ((df['Position'] == 'RM') | (df['Position'] == 'CM') | (df['Position'] == 'LM') | 
         (df['Position'] == 'RCM') | (df['Position'] == 'LCM')):
        return 'CM'
    elif ((df['Position'] == 'RAM') | (df['Position'] == 'CAM') | (df['Position'] == 'LAM')):
        return 'CAM'
    elif ((df['Position'] == 'RW') | (df['Position'] == 'LW') | (df['Position'] == 'RS') | 
          (df['Position'] == 'LS') | (df['Position'] == 'ST') | (df['Position'] == 'CF') | 
         (df['Position'] == 'RF') | (df['Position'] == 'LF')):
        return 'ST'
    else:
        return df.Position

# %%
# Get nationality count and only include nations with more than 200 players
nat_count = df.Nationality.value_counts()
nat_list = nat_count[nat_count > 200].index.tolist()

# %%
# Replace nationality to major nation binary
def major_nation(df):
    """
    This function turns the major nationality into binary.
    
    Parameter: 
        df['Nationality'](String): A string that represents player's
        nationality
        
    Returns:
        int: A int number represents if the player is in a major 
        nationality
    """
    if (df.Nationality in nat_list):
        return 1
    else:
        return 0

# %%
new_df = df.copy()

new_df['Real_Face'] = new_df.apply(face_to_binary, axis=1)
new_df['Left_Foot'] = new_df.apply(foot_to_binary, axis=1)
new_df['Change_Position'] = new_df.apply(change_position, axis=1)
new_df['Major_Nation'] = new_df.apply(major_nation, axis=1)

# %%
# Split work rate into 2 columns
workrate = new_df['Work Rate'].str.split('/ ', n=1, expand = True)

new_df['WorkRate1'] = workrate[0]
new_df['WorkRate2'] = workrate[1]

# Drop original columns
new_df = new_df.drop(['Real Face', 'Preferred Foot', 'Nationality', 'Work Rate'], axis=1)
new_df.head()
# Out:
#    Age  Overall  Potential        Value      Wage  International Reputation  \
# 0   31       94         94  110500000.0  565000.0                       5.0
# 1   33       94         94   77000000.0  405000.0                       5.0
# 2   26       92         93  118500000.0  290000.0                       5.0
# 4   27       91         92  102000000.0  355000.0                       4.0
# 5   27       91         91   93000000.0  340000.0                       4.0
#
#    Weak Foot  Skill Moves Position  Jersey Number    ...     GKHandling  \
# 0        4.0          4.0       RF           10.0    ...           11.0
# 1        4.0          5.0       ST            7.0    ...           11.0
# 2        5.0          5.0       LW           10.0    ...            9.0
# 4        5.0          4.0      RCM            7.0    ...           13.0
# 5        4.0          4.0       LF           10.0    ...           12.0
#
#   GKKicking GKPositioning GKReflexes Real_Face Left_Foot Change_Position  \
# ...

# %%
X = new_df.drop(['Overall'], axis = 1)
y = new_df['Overall']

X = pd.get_dummies(X)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=5)

print(X_test.shape, X_train.shape)
print(y_test.shape, y_train.shape)

lm_model = LinearRegression()
lm_model.fit(X_train, y_train)

y_preds = lm_model.predict(X_test)

print('R2 Score test: {0:.2f}'.format(r2_score(y_test, y_preds)))
print('RMSE test: {0:.2f}'.format(np.sqrt(mean_squared_error(y_test, y_preds))))
# Out:
# (4837, 636) (11285, 636)
# (4837,) (11285,)
# R2 Score test: 0.94
# RMSE test: 1.63
